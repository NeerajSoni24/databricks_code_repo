# %% [markdown]
# More Magic Commands
#
# how to change language
# - %py for Python
# - %scala for scala
# - %r for R

# %% [markdown]
# %fs ls to see list of items
#
# /databricks-datasets --> displays all the datasets
#
# - Databricks comes with some predefined datasets in your default dbfs directory

# %%
# %fs
ls /databricks-datasets

# %% [markdown]
# %fs
# ls /databricks-datasets/airlines
#
# - Displays all the files and folders

# %%
# %fs
ls /databricks-datasets/airlines

# %% [markdown]
# Using Linux shell commands
#
# %sh tail  --> to see last records.

# %%
# %sh 
tail /databricks-datasets/airlines/part-00000

# %%
# %lsmagic # To get list of all magic commands

# %% [markdown]
# To see the documentation for a particular magic command(?)
#
# for ex:
# %env?

# %%
# %env?

# %% [markdown]
# To see the source code of a magic command(??)
# for ex:
# env??

# %%
env??

# %%
pip??

# %% [markdown]
# Dbutils.help()
#
# - This module provides various utilities for users to interact with the rest of Databricks.

# %%
dbutils.help()

# %% [markdown]
# Dbutils.fs.help()
#
# - Provides utilities for working with FileSystems.

# %%
dbutils.fs.help()

# %%
dbutils.fs.help("cp")

# %% [markdown]
# ls with magic command

# %%
# %fs
ls /databricks-datasets/

# %% [markdown]
# ls without magic command

# %%
dbutils.fs.ls("/databricks-datasets")

# %%
for foldername in dbutils.fs.ls("/databricks-datasets"):
  print(foldername.path)
