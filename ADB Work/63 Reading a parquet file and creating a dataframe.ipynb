# %% [markdown]
# Reading a parquet file and creating a dataframe

# %% [markdown]
# Goto -> mystoragelakeadb6pmgroup -> dbfscontainer -> add folder 'parquetdata' -> upload -> titanic.parquet

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Spark DataFrames").getOrCreate()

df=spark.read.format("parquet").load("/mnt/files/parquetdata/titanic.parquet")

#or df=spark.read.parquet("/mnt/myfiles/parquetdata/titanic.parquet")
df.show()
