# %% [markdown]
# List out all the DBFS directories

# %%
# %fs
ls dbfs:/

# %%
# %fs
ls dbfs:/databricks-datasets/

# %% [markdown]
# same output without DBFS qualifier

# %%
# %fs
ls /databricks-datasets/

# %% [markdown]
# Other file systems

# %%
# %fs ls file:/

# %%
# %fs
mounts
