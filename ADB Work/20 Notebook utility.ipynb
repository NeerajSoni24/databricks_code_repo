# %%
dbutils.notebook.help()

# %% [markdown]
# This has 2 methods
# exit method
# run method - to call another notebook.

# %%
dbutils.notebook.run("./childnotebook",40)

# %%
dbutils.notebook.run("./childnotebook",40, {"message":"Hello from parent notebook"})
