-- %% [markdown]
-- After the DLT pipeline run, verify the data created by DLT pipeline tables.

-- %% [markdown]
-- See the data for final output table: Daily_Sales
--
-- Gold Layer: Materialised view

-- %%
%sql
select * from dev.demodb.daily_sales

-- %% [markdown]
-- Now verify the Customers tables:
--
-- Bronze: Customers_raw

-- %%
select * from dev.demodb.customers_raw

-- %% [markdown]
-- Silver: Customers_cleaned

-- %%
select * from dev.demodb.customers_cleaned

-- %% [markdown]
-- Silver: Customers

-- %%
select * from dev.demodb.customers

-- %% [markdown]
-- Invoices tables:
--
-- Bronze: Invoices_raw

-- %%
select * from dev.demodb.invoices_raw

-- %% [markdown]
-- Silver: Invoices_cleaned

-- %%
select * from dev.demodb.invoices_cleaned

-- %% [markdown]
-- Silver: Invoices

-- %%
select * from dev.demodb.invoices

-- %% [markdown]
-- How to execute sql commands by python code.

-- %%
%python
spark.sql ("select * from dev.demodb.invoices").display()

-- %%
%python
spark.sql ("select * from dev.demodb.customers").display()
