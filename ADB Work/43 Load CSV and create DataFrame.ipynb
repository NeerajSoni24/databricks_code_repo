# %%
emp_df = spark.read.csv("/mnt/files/csvdata/emp.csv",header=True)
emp_df.show()

# %%
emp1_df=spark.read.format("csv").option("header","true").load("/mnt/files/csvdata/emp.csv")
emp1_df.show()

# %%
# Read multiple CSV files
emps_df=spark.read.csv(["/mnt/files/csvdata/emp.csv","/mnt/files/csvdata/emp4.csv"],header=True)
emps_df.show()
