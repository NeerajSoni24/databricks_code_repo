# %% [markdown]
# Task3 :Reading a json file from ADLS and creating a DF

# %%
base_dir="/mnt/files"
df1=spark.read.format("json").load(f"{base_dir}/jsondata/person.json")
df1.show()

# %%
# alternative way to create dataframe from json.
df2=spark.read.format("json").load("/mnt/files/jsondata/person.json")
df2.show()
