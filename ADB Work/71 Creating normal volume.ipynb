# %% [markdown]
# Creating volumes

# %%
# %sql
create volume dev.demodb.volume1

# %% [markdown]
# When we dont specify the location of the volume, it stores in default storage. For ex. we have created our default storage metastore6pm-root in datalake. See next cell for entire path.

# %% [markdown]
# Storage location
# abfss://metastore6pm-root@mystoragelakeadb6pmgroup.dfs.core.windows.net/2d302ecc-5cd3-4de3-8970-63c608bb99f2/volumes/8d0ab2df-ef23-430e-903b-b147effb6c4d
