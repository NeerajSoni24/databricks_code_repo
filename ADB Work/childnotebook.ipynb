# %%
print("Hello..... from child notebook!!")

# %%
dbutils.widgets.help()

# %%
dbutils.widgets.text("message","","your input parameter")

# %%
p_message = dbutils.widgets.get("message")
print(p_message)

# %%
print("I am a child nootbook and I recevied:",p_message)

# %%
dbutils.notebook.exit("exit - 501")
