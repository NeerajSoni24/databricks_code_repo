# %% [markdown]
# Create a scehma

# %%
schema1="""eid int,
           ename string,
           sal double,
           sex string,
           dno int"""

# %% [markdown]
# Apply the schema while reading the text file.

# %%
df_text=spark.read.schema(schema1).csv("/mnt/files/data/emp4.txt")

#df1=spark.read.csv("/mnt/files/data/emp4.txt"

# %%
df_text.show()

# %%
display(df_text)
