# %%
# %fs
ls /mnt/

# %%
# %fs
ls /mnt/files

# %%
# %fs
ls /mnt/files/sampledata

# %% [markdown]
# create dataframe from json data

# %%
df = spark.read.format("json").load("/mnt/files/jsondata/person.json")

# %%
df.show()

# %% [markdown]
# another method of loading a json file

# %%
df = spark.read.json("/mnt/files/jsondata/person.json")
df.show()
